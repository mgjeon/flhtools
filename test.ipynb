# %%
import numpy as np

# %%
a = np.random.randn(3, 12, 6, 6)
ax = a[0]
ay = a[1]
az = a[2]

# %%
dx = 1
dy = 1
dz = 1

# %%
ax.shape
# Out:
# (12, 6, 6)

# %%
ax
# Out:
# array([[[ 6.72983390e-01,  1.66074571e+00,  5.50528290e-01,
#          -7.99603887e-01, -7.66027564e-01, -1.71086050e+00],
#         [-9.32573964e-01, -8.98972213e-01, -1.39730379e-01,
#           2.17137569e-01, -7.40589486e-01,  9.78652682e-01],
#         [-6.47801736e-01, -4.02725326e-01, -7.25084366e-01,
#          -7.42503328e-01, -2.28068007e-01, -8.27537950e-01],
#         [-1.14181081e+00, -6.72698987e-01, -9.99689584e-01,
#           2.39841408e-01,  1.94571996e-01, -6.14448058e-01],
#         [-1.02442075e+00, -6.13518960e-01, -9.49231635e-01,
#           1.37783715e+00,  1.03309085e+00,  3.46716675e-01],
#         [-7.36957614e-02,  1.00011096e+00,  1.56310746e-01,
#           4.87892202e-01,  8.16623762e-01, -2.08198482e-01]],
#
#        [[ 1.41951808e+00, -6.98342333e-01, -1.12361698e+00,
#           3.41056399e-02,  7.50034598e-01, -8.54280437e-01],
#         [ 5.79957291e-01,  1.19997329e+00, -2.44260323e-01,
# ...
